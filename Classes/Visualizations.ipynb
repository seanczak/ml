# %%
import pandas as pd, numpy as np

import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('ggplot')
plt.style.use(['dark_background'])

# %%
df = pd.DataFrame(np.random.uniform(size=(40000,6)))
df.head()
# Out:
#           0         1         2         3         4         5
# 0  0.924472  0.005606  0.570943  0.374909  0.458521  0.115224
# 1  0.812407  0.919906  0.721691  0.498537  0.293610  0.499153
# 2  0.504993  0.399532  0.321328  0.450270  0.193331  0.549996
# 3  0.280912  0.323466  0.108046  0.642752  0.805625  0.348664
# 4  0.978265  0.692013  0.237575  0.858127  0.431478  0.927090

# %%
# plt.rcParams.update(plt.rcParamsDefault)
for col in df:
    plt.figure(); plt.grid(alpha=0)
    df[col].hist(bins=100)

# %%
for col in df:
    print(col)
# Out:
# 0
# 1
# 2
# 3
